# %% [markdown]
# <a href="https://colab.research.google.com/github/dim447/data_analyst/blob/main/need_delivery_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Загружаем данные
import pandas as pd
# import numpy as np
# from datetime import datetime


df = pd.read_csv('/content/data_DV.csv', sep=',')
df1 = pd.read_csv('/content/data_kavkas.csv', sep=',')
df2 = pd.read_csv('/content/data_kazan.csv', sep=',')
df3 = pd.read_csv('/content/data_kras.csv', sep=',')
df4 = pd.read_csv('/content/data_krd.csv', sep=',')
df5 = pd.read_csv('/content/data_spb.csv', sep=',')
df6 = pd.read_csv('/content/data_moscow.csv', sep=',')
df7 = pd.read_csv('/content/data_novosib.csv', sep=',')
df8 = pd.read_csv('/content/data_omsk.csv', sep=',')
df9 = pd.read_csv('/content/data_rostov.csv', sep=',')
df10 = pd.read_csv('/content/data_samara.csv', sep=',')
df11 = pd.read_csv('/content/data_tumen.csv', sep=',')
df12 = pd.read_csv('/content/data_ufa.csv', sep=',')
df13 = pd.read_csv('/content/data_ural.csv', sep=',')
df14 = pd.read_csv('/content/data_volga.csv', sep=',')
df15 = pd.read_csv('/content/data_voron.csv', sep=',')

# %%
df15.head(10)
# Out:
#                Кластер отгрузки  \
# 0                       Воронеж
# 1                       Воронеж
# 2                       Воронеж
# 3                Ростов-на-Дону
# 4                       Воронеж
# 5                Ростов-на-Дону
# 6                       Воронеж
# 7                     Волгоград
# 8  Москва, МО и Дальние регионы
# 9                        Самара
#
#                                  Наименование товара  Заказы отгрузки  \
# 0  Чайный напиток травяной Ромашки цветки ф/п 1,5...              3.0
# 1  Чай травяной детская линия Сказка на ночь ф/п ...              2.0
# 2     Чай травяной Домбайский вальс Облепиха 2 пачки              2.0
# 3  Чайный напиток травяной Шалфея листья ф/п 1,5г...              2.0
# 4                              Фитосбор "Для печени"              1.0
# 5  Чай травяной детская линия Комфорт в боботике ...              1.0
# 6  Чай травяной Домбайский вальс Лесные ягоды ф/п...              1.0
# 7  Чай травяной Домбайский вальс Шиповник ф/п 1.5...              1.0
# 8  Чай травяной Домбайский вальс Шиповник ф/п 1.5...              1.0
# 9  Чай травяной Домбайский вальс Шиповник ф/п 1.5...              1.0
#
#    Заказы доставки  Заказы всего  Склад  В пути  Остатки  Обор-сть  \
# 0              0.0           3.0    NaN     NaN      NaN  0.107143
# 1              0.0           2.0   11.0     0.0     11.0  0.071429
# 2              0.0           2.0    1.0     0.0      1.0  0.071429
# 3              0.0           2.0    NaN     NaN      NaN  0.071429
# 4              0.0           1.0    1.0     0.0      1.0  0.035714
# 5              0.0           1.0    NaN     NaN      NaN  0.035714
# 6              0.0           1.0    1.0     0.0      1.0  0.035714
# 7              2.0           3.0    NaN     NaN      NaN  0.107143
# 8              2.0           3.0   14.0     0.0     14.0  0.107143
# 9              2.0           3.0    7.0     0.0      7.0  0.107143
#
#    Остаток дней  Поставка
# 0           NaN         4
# 1         154.0         0
# 2          14.0         2
# 3           NaN         3
# 4          28.0         0
# 5           NaN         2
# 6          28.0         0
# 7           NaN         4
# 8         131.0         0
# 9          65.0         0

# %%
df = df[df['Кластер отгрузки'] == 'Дальний Восток']
df1 = df1[df1['Кластер отгрузки'] == 'Кавказ']
df2 = df2[df2['Кластер отгрузки'] == 'Казань']
df3 = df3[df3['Кластер отгрузки'] == 'Красноярск']
df4 = df4[df4['Кластер отгрузки'] == 'Краснодар']
df5 = df5[df5['Кластер отгрузки'] == 'Санкт-Петербург и СЗО']
df6 = df6[df6['Кластер отгрузки'] == 'Москва, МО и Дальние регионы']
df7 = df7[df7['Кластер отгрузки'] == 'Новосибирск']
df8 = df8[df8['Кластер отгрузки'] == 'Омск']
df9 = df9[df9['Кластер отгрузки'] == 'Ростов-на-Дону']
df10 = df10[df10['Кластер отгрузки'] == 'Самара']
df11 = df11[df11['Кластер отгрузки'] == 'Тюмень']
df12 = df12[df12['Кластер отгрузки'] == 'Уфа']
df13 = df13[df13['Кластер отгрузки'] == 'Урал']
df14 = df14[df14['Кластер отгрузки'] == 'Волгоград']
df15 = df15[df15['Кластер отгрузки'] == 'Воронеж']

# %%
df_all = pd.concat([df, df1, df3, df4, df5, df6, df7, df8, df2, df9, df10, df11, df12, df13, df14, df15])
# df_all.to_excel("/content/need_new_all.xlsx", index=False)

# %%
df_all.head(10)
# Out:
#     Кластер отгрузки                                Наименование товара  \
# 14    Дальний Восток                                                NaN
# 35    Дальний Восток     Fermentus, суспензия ферментированной хлореллы
# 56    Дальний Восток  Fermentus, суспензия ферментированной хлореллы...
# 77    Дальний Восток  БАД к пище "Целебная поляна" "Друг Императора"...
# 98    Дальний Восток                         Двухсторонняя куртка Lebek
# 119   Дальний Восток                       Куртка женская Barbara Lebek
# 140   Дальний Восток                           Куртка женская Dixi Coat
# 161   Дальний Восток  Набор ароматических свечей подарочный 4 штуки ...
# 182   Дальний Восток                       Пальто женское Barbara Lebek
# 203   Дальний Восток                           Пальто женское Dixi Coat
#
#      Заказы отгрузки  Заказы доставки  Заказы всего  Склад  В пути  Остатки  \
# 14               NaN              NaN           NaN    NaN     NaN      NaN
# 35               NaN              NaN           NaN    NaN     NaN      NaN
# 56               NaN              NaN           NaN    NaN     NaN      NaN
# 77               NaN              NaN           NaN    NaN     NaN      NaN
# 98               NaN              NaN           NaN    NaN     NaN      NaN
# 119              NaN              NaN           NaN    NaN     NaN      NaN
# 140              NaN              NaN           NaN    NaN     NaN      NaN
# 161              NaN              NaN           NaN    NaN     NaN      NaN
# 182              NaN              NaN           NaN    NaN     NaN      NaN
# 203              NaN              NaN           NaN    NaN     NaN      NaN
#
#      Обор-сть  Остаток дней  Поставка
# 14        NaN           NaN         0
# 35        NaN           NaN         0
# 56        NaN           NaN         0
# 77        NaN           NaN         0
# 98        NaN           NaN         0
# 119       NaN           NaN         0
# 140       NaN           NaN         0
# 161       NaN           NaN         0
# 182       NaN           NaN         0
# 203       NaN           NaN         0

# %%
df_all['Кластер отгрузки'].unique()
# df.df['Кластеры отгрузки Скл'].unique()
# Out:
# array(['Дальний Восток', 'Кавказ', 'Красноярск', 'Краснодар',
#        'Санкт-Петербург и СЗО', 'Москва, МО и Дальние регионы',
#        'Новосибирск', 'Омск', 'Казань', 'Ростов-на-Дону', 'Самара',
#        'Тюмень', 'Урал', 'Волгоград', 'Воронеж'], dtype=object)

# %%
# create a excel writer object
with pd.ExcelWriter("/content/need_new.xlsx") as writer:

    # use to_excel function and specify the sheet_name and index
    # to store the dataframe in specified sheet
    df.to_excel(writer, sheet_name="Дальний Восток", index=False)
    df1.to_excel(writer, sheet_name="Кавказ", index=False)
    df2.to_excel(writer, sheet_name="Казань", index=False)
    df3.to_excel(writer, sheet_name="Красноярск", index=False)
    df4.to_excel(writer, sheet_name="Краснодар", index=False)
    df5.to_excel(writer, sheet_name="Санкт-Петербург и СЗО", index=False)
    df6.to_excel(writer, sheet_name="Москва, МО и Дальние регионы", index=False)
    df7.to_excel(writer, sheet_name="Новосибирск", index=False)
    df8.to_excel(writer, sheet_name="Омск", index=False)
    df9.to_excel(writer, sheet_name="Ростов-на-Дону", index=False)
    df10.to_excel(writer, sheet_name="Самара", index=False)
    df11.to_excel(writer, sheet_name="Тюмень", index=False)
    df12.to_excel(writer, sheet_name="Уфа", index=False)
    df13.to_excel(writer, sheet_name="Урал", index=False)
    df14.to_excel(writer, sheet_name="Волгоград", index=False)
    df15.to_excel(writer, sheet_name="Воронеж", index=False)
    df_all.to_excel(writer, sheet_name="Все регионы", index=False)
