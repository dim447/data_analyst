# %% [markdown]
# <a href="https://colab.research.google.com/github/dim447/data_analyst/blob/main/need_delivery_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Загружаем данные
import pandas as pd
# import numpy as np
# from datetime import datetime

df = pd.read_csv('/content/data.csv', sep=',')
# df = pd.read_csv('/content/data_MV.csv', sep=',')
# df1 = pd.read_csv('/content/data_MZ.csv', sep=',')
# df2 = pd.read_csv('/content/data_centr.csv', sep=',')
# df3 = pd.read_csv('/content/data_don.csv', sep=',')
# df4 = pd.read_csv('/content/data_sib.csv', sep=',')
# df5 = pd.read_csv('/content/data_spb.csv', sep=',')
# df6 = pd.read_csv('/content/data_ural.csv', sep=',')
# df7 = pd.read_csv('/content/data_volga.csv', sep=',')
# df8 = pd.read_csv('/content/data_yug.csv', sep=',')
# df9 = pd.read_csv('/content/data_DV.csv', sep=',')

# %%
df.head(10)
# Out:
#                Кластер отгрузки  \
# 0  Москва, МО и Дальние регионы
# 1                     Краснодар
# 2  Москва, МО и Дальние регионы
# 3  Москва, МО и Дальние регионы
# 4  Москва, МО и Дальние регионы
# 5  Москва, МО и Дальние регионы
# 6  Москва, МО и Дальние регионы
# 7  Москва, МО и Дальние регионы
# 8                     Краснодар
# 9  Москва, МО и Дальние регионы
#
#                                  Наименование товара  Заказы отгрузки  \
# 0  Чайный напиток травяной Пустырника трава ф/п 1...             31.0
# 1  Чай травяной Друг Вашей поджелудочной железы 2...             25.0
# 2  Чай травяной Друг Вашей поджелудочной железы 2...             25.0
# 3            Чай травяной Друг Вашего сердца 2 пачки             22.0
# 4  Чайный напиток травяной Ромашки цветки ф/п 1,5...             20.0
# 5               Чай травяной Друг Вашего сна 2 пачки             19.0
# 6          Чай травяной Друг Вашего давления 2 пачки             18.0
# 7  Чай травяной детская линия Сказка на ночь ф/п ...             17.0
# 8            Чай травяной Друг Ваших бронхов 2 пачки             17.0
# 9  Чайный напиток травяной Череды трава ф/п 1,5г ...             16.0
#
#    Заказы доставки  Заказы всего  Склад  В пути  Остатки  Обор-сть  \
# 0             23.0          54.0    4.0    16.0     20.0  1.928571
# 1             93.0         118.0   15.0     0.0     15.0  4.214286
# 2             93.0         118.0    0.0    18.0     18.0  4.214286
# 3             27.0          49.0    4.0     8.0     12.0  1.750000
# 4             23.0          43.0    0.0    16.0     16.0  1.535714
# 5             20.0          39.0    5.0    12.0     17.0  1.392857
# 6             33.0          51.0    0.0    12.0     12.0  1.821429
# 7             24.0          41.0    7.0    12.0     19.0  1.464286
# 8             38.0          55.0    3.0     0.0      3.0  1.964286
# 9             25.0          41.0    0.0    20.0     20.0  1.464286
#
#    Остаток дней  Поставка ALL
# 0          10.0            20
# 1           4.0            18
# 2           4.0            15
# 3           7.0            17
# 4          10.0            10
# 5          12.0             8
# 6           7.0            11
# 7          13.0             3
# 8           2.0            19
# 9          14.0             2

# %%
df.to_excel('/content/need_all.xlsx',  index=False)
