# %% [markdown]
# <a href="https://colab.research.google.com/github/dim447/data_analyst/blob/main/need_delivery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Загружаем данные и объединяем семь датасетов
import pandas as pd
import numpy as np
from datetime import datetime


df = pd.read_csv('/content/need_delivery_march.csv', sep=',')

# %%
df.head(10)
# Out:
#                                  Наименование товара      Кластеры отгрузки  \
# 0  Чай травяной детская линия Сказка на ночь ф/п ...                  Центр
# 1  Чай травяной Друг Вашей поджелудочной железы 2...               Поволжье
# 2       Чай травяной Друг Вашего сердца ф/п 1.5г №20           Москва-Запад
# 3  Чайный напиток травяной листья Брусники ф/п 1,...                   Урал
# 4  Чайный напиток травяной Череды трава ф/п 1,5г ...  Санкт-Петербург и СЗО
# 5  Чай травяной детская линия Комфорт в боботике ...                   Урал
# 6  Чай травяной детская линия Сказка на ночь ф/п ...                   Урал
# 7     Чай травяной Друг Вашего давления ф/п 1.5г №20                  Центр
# 8            Чай травяной Друг Ваших бронхов 2 пачки               Поволжье
# 9  Чайный напиток травяной Пустырника трава ф/п 1...                  Центр
#
#    Продажи  Остатки  Поставка
# 0     14.0      2.0      16.0
# 1     10.0      NaN      13.0
# 2      6.0      NaN       8.0
# 3      6.0      NaN       8.0
# 4      6.0      NaN       8.0
# 5      5.0      NaN       7.0
# 6      5.0      NaN       7.0
# 7      5.0      NaN       7.0
# 8      5.0      NaN       7.0
# 9      6.0      1.0       7.0
