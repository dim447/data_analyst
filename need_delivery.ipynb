# %% [markdown]
# <a href="https://colab.research.google.com/github/dim447/data_analyst/blob/main/need_delivery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Загружаем данные
import pandas as pd
# import numpy as np
# from datetime import datetime


df = pd.read_csv('/content/data_MV.csv', sep=',')
df1 = pd.read_csv('/content/data_MZ.csv', sep=',')
# df2 = pd.read_csv('/content/data_centr.csv', sep=',')
df3 = pd.read_csv('/content/data_don.csv', sep=',')
df4 = pd.read_csv('/content/data_sib.csv', sep=',')
df5 = pd.read_csv('/content/data_spb.csv', sep=',')
df6 = pd.read_csv('/content/data_ural.csv', sep=',')
df7 = pd.read_csv('/content/data_volga.csv', sep=',')
df8 = pd.read_csv('/content/data_yug.csv', sep=',')
df9 = pd.read_csv('/content/data_DV.csv', sep=',')

# %%
df.head(10)
# Out:
#               Кластер отгрузки СКЛ  \
# 0  Москва-Восток и Дальние регионы
# 1  Москва-Восток и Дальние регионы
# 2  Москва-Восток и Дальние регионы
# 3  Москва-Восток и Дальние регионы
# 4  Москва-Восток и Дальние регионы
# 5  Москва-Восток и Дальние регионы
# 6  Москва-Восток и Дальние регионы
# 7  Москва-Восток и Дальние регионы
# 8  Москва-Восток и Дальние регионы
# 9  Москва-Восток и Дальние регионы
#
#                                  Наименование товара  Заказы отгрузки  \
# 0  Чайный напиток травяной листья Брусники ф/п 1,...             11.0
# 1  Чай травяной детская линия Сказка на ночь ф/п ...             10.0
# 2  Чай травяной детская линия Комфорт в боботике ...              8.0
# 3  Чай травяной Друг Вашей поджелудочной железы 2...              8.0
# 4           Чай травяной Друг Вашего желудка 2 пачки              7.0
# 5  Чайный напиток травяной Пустырника трава ф/п 1...              6.0
# 6              Чай травяной Друг Ваших почек 2 пачки              5.0
# 7  Чайный напиток травяной Ромашки цветки ф/п 1,5...              5.0
# 8  Чайный напиток травяной Шалфея листья ф/п 1,5г...              5.0
# 9               Чай травяной Друг Вашего сна 2 пачки              4.0
#
#    Заказы доставки  Заказы всего  Склад  В пути  Остатки  Обор-сть  \
# 0              0.0          11.0    0.0     5.0      5.0  0.314286
# 1              0.0          10.0   14.0     0.0     14.0  0.285714
# 2              1.0           9.0    6.0     6.0     12.0  0.257143
# 3              0.0           8.0   13.0     0.0     13.0  0.228571
# 4              0.0           7.0    8.0     2.0     10.0  0.200000
# 5              0.0           6.0   16.0     0.0     16.0  0.171429
# 6              0.0           5.0    0.0     7.0      7.0  0.142857
# 7              2.0           7.0    1.0     5.0      6.0  0.200000
# 8              0.0           5.0    0.0     2.0      2.0  0.142857
# 9              0.0           4.0    5.0     0.0      5.0  0.114286
#
#    Остаток дней  Поставка
# 0          16.0         9
# 1          49.0         0
# 2          47.0         0
# 3          57.0         0
# 4          50.0         0
# 5          93.0         0
# 6          49.0         0
# 7          30.0         3
# 8          14.0         5
# 9          44.0         0

# %%
df = df[df['Кластер отгрузки СКЛ'] == 'Москва-Восток и Дальние регионы']
df1 = df1[df1['Кластер отгрузки СКЛ'] == 'Москва-Запад']
# df2 = df2[df2['Кластеры отгрузки Скл'] == 'Центр']
df3 = df3[df3['Кластер отгрузки СКЛ'] == 'Дон']
df4 = df4[df4['Кластер отгрузки СКЛ'] == 'Сибирь']
df5 = df5[df5['Кластер отгрузки СКЛ'] == 'Санкт-Петербург и СЗО']
df6 = df6[df6['Кластер отгрузки СКЛ'] == 'Урал']
df7 = df7[df7['Кластер отгрузки СКЛ'] == 'Поволжье']
df8 = df8[df8['Кластер отгрузки СКЛ'] == 'Юг']
df9 = df9[df9['Кластер отгрузки СКЛ'] == 'Дальний Восток']


# df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Кластер отгрузки СКЛ'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-03cd8611c53c> in <cell line: 10>()
#       8 df7 = df7[df7['Кластер отгрузки СКЛ'] == 'Поволжье']
#       9 df8 = df8[df8['Кластер отгрузки СКЛ'] == 'Юг']
# ---> 10 df9 = df9[df9['Кластер отгрузки СКЛ'] == 'Дальний Восток']
#      11
#      12
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Кластер отгрузки СКЛ'

# %%
df_all = pd.concat([df1, df3, df4, df5, df6, df7, df8, df9, df])
# df_all.to_excel("/content/need_new_all.xlsx", index=False)

# %%
df_all['Кластеры отгрузки Скл'].unique()
# df.df['Кластеры отгрузки Скл'].unique()
# Out:
# array([nan, 'Сибирь', 'Урал', 'Поволжье',
#        'Москва-Восток и Дальние регионы', 'Дон', 'Калининград',
#        'Москва-Запад', 'Санкт-Петербург и СЗО', 'Центр', 'Юг'],
#       dtype=object)

# %%
# create a excel writer object
with pd.ExcelWriter("/content/need_new.xlsx") as writer:

    # use to_excel function and specify the sheet_name and index
    # to store the dataframe in specified sheet
    df.to_excel(writer, sheet_name="Москва Восток", index=False)
    df1.to_excel(writer, sheet_name="Москва Запад", index=False)
    # df2.to_excel(writer, sheet_name="Центр", index=False)
    df3.to_excel(writer, sheet_name="Дон", index=False)
    df4.to_excel(writer, sheet_name="Сибирь", index=False)
    df5.to_excel(writer, sheet_name="Санкт-Петербург и СЗО", index=False)
    df6.to_excel(writer, sheet_name="Урал", index=False)
    df7.to_excel(writer, sheet_name="Поволжье", index=False)
    df8.to_excel(writer, sheet_name="Юг", index=False)
    df9.to_excel(writer, sheet_name="ДВ", index=False)
    df_all.to_excel(writer, sheet_name="Все регионы", index=False)


# df.to_excel('/content/need_new.xlsx', sheet_name='Москва Восток', index=False)
# df1.to_excel('/content/need_new.xlsx', sheet_name='Москва Запад', index=False)
# # df1.to_excel('/content/need_MZ.xlsx')
# df2.to_excel('/content/need_centr.xlsx')
# df3.to_excel('/content/need_don.xlsx')
# df4.to_excel('/content/need_sib.xlsx')
# df5.to_excel('/content/need_spb.xlsx')
# df6.to_excel('/content/need_ural.xlsx')
# df7.to_excel('/content/need_volga.xlsx')
# df8.to_excel('/content/need_yug.xlsx')
# df_new.to_csv('/content/orders_new.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-86a8260b6d13> in <cell line: 2>()
#      14     df8.to_excel(writer, sheet_name="Юг", index=False)
#      15     df9.to_excel(writer, sheet_name="ДВ", index=False)
# ---> 16     df_all.to_excel(writer, sheet_name="Все регионы", index=False)
#      17
#      18
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options)
#    2250             inf_rep=inf_rep,
#    2251         )
# -> 2252         formatter.write(
#    2253             excel_writer,
#    2254             sheet_name=sheet_name,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     938
#     939         try:
# --> 940             writer._write_cells(
#     941                 formatted_cells,
#     942                 sheet_name,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_openpyxl.py in _write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     484
#     485         for cell in cells:
# --> 486             xcell = wks.cell(
#     487                 row=startrow + cell.row + 1, column=startcol + cell.col + 1
#     488             )
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/worksheet.py in cell(self, row, column, value)
#     242             raise ValueError("Row or column values must be at least 1")
#     243
# --> 244         cell = self._get_cell(row, column)
#     245         if value is not None:
#     246             cell.value = value
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/worksheet.py in _get_cell(self, row, column)
#     258         coordinate = (row, column)
#     259         if not coordinate in self._cells:
# --> 260             cell = Cell(self, row=row, column=column)
#     261             self._add_cell(cell)
#     262         return self._cells[coordinate]
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/cell/cell.py in __init__(self, worksheet, row, column, value, style_array)
#     106                  )
#     107
# --> 108     def __init__(self, worksheet, row=None, column=None, value=None, style_array=None):
#     109         super(Cell, self).__init__(worksheet, style_array)
#     110         self.row = row
#
# KeyboardInterrupt:
