# %% [markdown]
# <a href="https://colab.research.google.com/github/dim447/data_analyst/blob/main/%202to1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Задачи исследования**
#
# ### Загружаем данные и меняем с 2 пачки на 1.

# %%
### Загружаем данные продаж за период (orders.csv)
import pandas as pd
import numpy as np
from datetime import datetime


df = pd.read_csv('/content/orders.csv', sep=';')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 25 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Номер заказа                          8 non-null      object
#  1   Номер отправления                     8 non-null      object
#  2   Принят в обработку                    8 non-null      object
#  3   Дата отгрузки                         8 non-null      object
#  4   Статус                                8 non-null      object
#  5   Дата доставки                         0 non-null      float64
#  6   Фактическая дата передачи в доставку  3 non-null      object
#  7   Сумма отправления                     8 non-null      float64
#  8   Код валюты отправления                8 non-null      object
#  9   Наименование товара                   8 non-null      object
#  10  OZON id                               8 non-null      int64
#  11  Артикул                               8 non-null      int64
#  12  Ваша цена                             8 non-null      float64
#  13  Код валюты товара                     8 non-null      object
#  14  Оплачено покупателем                  8 non-null      float64
#  15  Код валюты покупателя                 8 non-null      object
#  16  Количество                            8 non-null      int64
#  17  Стоимость доставки                    0 non-null      float64
#  18  Связанные отправления                 0 non-null      float64
#  19  Выкуп товара                          0 non-null      float64
#  20  Цена товара до скидок                 8 non-null      float64
#  21  Скидка %                              8 non-null      object
#  22  Скидка руб                            8 non-null      float64
#  23  Акции                                 8 non-null      object
#  24  Объемный вес товаров, кг              8 non-null      float64
# dtypes: float64(10), int64(3), object(12)
# memory usage: 1.7+ KB

# %%
### Убираем товары со статусом "Отменен"
df = df.loc[df['Статус'] != 'Отменён']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 0 to 7
# Data columns (total 25 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Номер заказа                          8 non-null      object
#  1   Номер отправления                     8 non-null      object
#  2   Принят в обработку                    8 non-null      object
#  3   Дата отгрузки                         8 non-null      object
#  4   Статус                                8 non-null      object
#  5   Дата доставки                         0 non-null      float64
#  6   Фактическая дата передачи в доставку  3 non-null      object
#  7   Сумма отправления                     8 non-null      float64
#  8   Код валюты отправления                8 non-null      object
#  9   Наименование товара                   8 non-null      object
#  10  OZON id                               8 non-null      int64
#  11  Артикул                               8 non-null      int64
#  12  Ваша цена                             8 non-null      float64
#  13  Код валюты товара                     8 non-null      object
#  14  Оплачено покупателем                  8 non-null      float64
#  15  Код валюты покупателя                 8 non-null      object
#  16  Количество                            8 non-null      int64
#  17  Стоимость доставки                    0 non-null      float64
#  18  Связанные отправления                 0 non-null      float64
#  19  Выкуп товара                          0 non-null      float64
#  20  Цена товара до скидок                 8 non-null      float64
#  21  Скидка %                              8 non-null      object
#  22  Скидка руб                            8 non-null      float64
#  23  Акции                                 8 non-null      object
#  24  Объемный вес товаров, кг              8 non-null      float64
# dtypes: float64(10), int64(3), object(12)
# memory usage: 1.6+ KB

# %%
### приводим значения артикулов с формату "Моя торговля"
df['Артикул'] = df['Артикул'].apply(lambda x: str(x)[:5] if len(str(x)) == 6
                                    else str(x)[:3] if len(str(x)) == 4
                                    else str(x))

# %%
### Оставляем для импорта только эти данные
df_new = df[['Наименование товара', 'Артикул', 'Сумма отправления', 'Количество']]

# %%
### Если в названии есть "2 пачки", то меняем количество на 2 и стоимость делим на 2
sub ='2 пачки'
df_new["Indexes"]= df_new['Наименование товара'].str.find(sub)
df_new.loc[df_new["Indexes"] >= 0, 'Количество'] = 2
df_new.loc[df_new["Indexes"] >= 0, 'Сумма отправления'] = df['Сумма отправления'] / 2
df_new.head(10)
# Out:
# /tmp/ipython-input-9-75755265.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["Indexes"]= df_new['Наименование товара'].str.find(sub)
#                                  Наименование товара Артикул  \
# 0  "Друг Императора" Биологически активная добавк...   68978
# 1  "Друг Императора" Биологически активная добавк...   68978
# 2  "Друг Императора" Биологически активная добавк...   68978
# 3  "Друг Императора" Биологически активная добавк...   68978
# 4  Шалфея листья Биологически активная добавка к ...   76499
# 5  Чай травяной детская линия Сказка на ночь ф/п ...   71002
# 6  Чай травяной детская линия Сказка на ночь ф/п ...   71002
# 7  "Целебная поляна" Травяной сбор / Друг Вашего ...   68976
#
#    Сумма отправления  Количество  Indexes
# 0              146.5           2       73
# 1              146.5           2       73
# 2              146.5           2       73
# 3              146.5           2       73
# 4              189.5           2       78
# 5              183.0           1       -1
# 6              183.0           1       -1
# 7              176.0           2       57

# %%
### Сохраняем в файл для импорта
df_new.to_excel('/content/orders_new.xlsx')
# df_new.to_csv('/content/orders_new.csv')
