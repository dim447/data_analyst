# %% [markdown]
# <a href="https://colab.research.google.com/github/dim447/data_analyst/blob/main/%202to1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Задачи исследования**
#
# ### Загружаем данные и меняем с 2 пачки на 1.

# %%
### Загружаем данные и объединяем семь датасетов
import pandas as pd
import numpy as np
from datetime import datetime


df = pd.read_csv('/content/orders.csv', sep=';')

# %%
df.head(5)
# Out:
#     Номер заказа Номер отправления   Принят в обработку        Дата отгрузки  \
# 0  83383408-0143   83383408-0143-7  2024-10-27 20:52:33  2024-10-31 01:00:00
# 1  02710304-1619   02710304-1619-1  2024-10-27 20:50:02  2024-10-28 20:00:00
# 2  02265339-0158   02265339-0158-2  2024-10-27 20:24:19  2024-10-28 08:00:00
# 3  43831879-0143   43831879-0143-1  2024-10-27 19:39:36  2024-10-28 09:30:00
# 4  42590669-0116   42590669-0116-2  2024-10-27 19:23:07  2024-10-28 01:30:00
#
#              Статус  Дата доставки Фактическая дата передачи в доставку  \
# 0           Отменён            NaN                                  NaN
# 1  Ожидает отгрузки            NaN                                  NaN
# 2      Доставляется            NaN                  2024-10-28 08:19:45
# 3  Ожидает отгрузки            NaN                                  NaN
# 4      Доставляется            NaN                  2024-10-28 02:54:05
#
#    Сумма отправления Код валюты отправления  \
# 0              320.0                    RUB
# 1              333.0                    RUB
# 2              359.0                    RUB
# 3              189.0                    RUB
# 4              333.0                    RUB
#
#                                  Наименование товара  ...  \
# 0  Чай травяной Друг Ваших бронхов 2 пачки /40 фи...  ...
# 1  Чайный напиток травяной листья Брусники ф/п 1,...  ...
# 2  Чай травяной Друг Вашего желудка 2 пачки /40 ф...  ...
# 3  Чай травяной детская линия Сказка на ночь ф/п ...  ...
# 4  Чайный напиток травяной листья Брусники ф/п 1,...  ...
#
#    Код валюты покупателя  Количество  Стоимость доставки  \
# 0                    RUB           1                 NaN
# 1                    RUB           1                 NaN
# 2                    RUB           1                 NaN
# 3                    RUB           1                 NaN
# 4                    RUB           1                 NaN
#
#   Связанные отправления  Выкуп товара Цена товара до скидок  Скидка %  \
# 0                   NaN           NaN                796.88       60%
# 1                   NaN           NaN                799.00       58%
# 2                   NaN           NaN                799.00       55%
# 3                   NaN           NaN                450.00       58%
# 4                   NaN           NaN                799.00       58%
#
#    Скидка руб                                              Акции  \
# 0      476.88  Системная виртуальная скидка селлера, Бустинг ...
# 1      466.00  Системная виртуальная скидка селлера, Бустинг ...
# 2      440.00  Системная виртуальная скидка селлера, Бустинг ...
# 3      261.00  Системная виртуальная скидка селлера, Бустинг ...
# 4      466.00  Системная виртуальная скидка селлера, Бустинг ...
#
#    Объемный вес товаров, кг
# 0                       0.2
# 1                       0.2
# 2                       0.2
# 3                       0.1
# 4                       0.2
#
# [5 rows x 25 columns]

# %%
df = df.loc[df['Статус'] != 'Отменён']
df.head(5)
# Out:
#     Номер заказа Номер отправления   Принят в обработку        Дата отгрузки  \
# 1  02710304-1619   02710304-1619-1  2024-10-27 20:50:02  2024-10-28 20:00:00
# 2  02265339-0158   02265339-0158-2  2024-10-27 20:24:19  2024-10-28 08:00:00
# 3  43831879-0143   43831879-0143-1  2024-10-27 19:39:36  2024-10-28 09:30:00
# 4  42590669-0116   42590669-0116-2  2024-10-27 19:23:07  2024-10-28 01:30:00
# 5  38372511-0050   38372511-0050-2  2024-10-27 19:10:31  2024-10-28 15:00:00
#
#              Статус  Дата доставки Фактическая дата передачи в доставку  \
# 1  Ожидает отгрузки            NaN                                  NaN
# 2      Доставляется            NaN                  2024-10-28 08:19:45
# 3  Ожидает отгрузки            NaN                                  NaN
# 4      Доставляется            NaN                  2024-10-28 02:54:05
# 5  Ожидает отгрузки            NaN                                  NaN
#
#    Сумма отправления Код валюты отправления  \
# 1              333.0                    RUB
# 2              359.0                    RUB
# 3              189.0                    RUB
# 4              333.0                    RUB
# 5              189.0                    RUB
#
#                                  Наименование товара  ...  \
# 1  Чайный напиток травяной листья Брусники ф/п 1,...  ...
# 2  Чай травяной Друг Вашего желудка 2 пачки /40 ф...  ...
# 3  Чай травяной детская линия Сказка на ночь ф/п ...  ...
# 4  Чайный напиток травяной листья Брусники ф/п 1,...  ...
# 5  Чай травяной детская линия Комфорт в боботике ...  ...
#
#    Код валюты покупателя  Количество  Стоимость доставки  \
# 1                    RUB           1                 NaN
# 2                    RUB           1                 NaN
# 3                    RUB           1                 NaN
# 4                    RUB           1                 NaN
# 5                    RUB           1                 NaN
#
#   Связанные отправления  Выкуп товара Цена товара до скидок  Скидка %  \
# 1                   NaN           NaN                 799.0       58%
# 2                   NaN           NaN                 799.0       55%
# 3                   NaN           NaN                 450.0       58%
# 4                   NaN           NaN                 799.0       58%
# 5                   NaN           NaN                 399.0       53%
#
#    Скидка руб                                              Акции  \
# 1       466.0  Системная виртуальная скидка селлера, Бустинг ...
# 2       440.0  Системная виртуальная скидка селлера, Бустинг ...
# 3       261.0  Системная виртуальная скидка селлера, Бустинг ...
# 4       466.0  Системная виртуальная скидка селлера, Бустинг ...
# 5       210.0  Бустинг х2. 11.11 и Черная пятница, Системная ...
#
#    Объемный вес товаров, кг
# 1                       0.2
# 2                       0.2
# 3                       0.1
# 4                       0.2
# 5                       0.1
#
# [5 rows x 25 columns]

# %%
df_new = df[['Наименование товара', 'Артикул', 'Итоговая стоимость товара', 'Количество']]
df_new.head(5)
# Out:
#                                  Наименование товара  Артикул  \
# 1  Чайный напиток травяной листья Брусники ф/п 1,...   697461
# 2  Чай травяной Друг Вашего желудка 2 пачки /40 ф...   689741
# 3  Чай травяной детская линия Сказка на ночь ф/п ...    71002
# 4  Чайный напиток травяной листья Брусники ф/п 1,...   697461
# 5  Чай травяной детская линия Комфорт в боботике ...    71003
#
#    Итоговая стоимость товара  Количество
# 1                      333.0           1
# 2                      359.0           1
# 3                      189.0           1
# 4                      333.0           1
# 5                      189.0           1

# %%
sub ='2 пачки'
df_new["Indexes"]= df_new['Наименование товара'].str.find(sub)
df_new.loc[df_new["Indexes"] >= 0, 'Количество'] = 2
df_new.loc[df_new["Indexes"] >= 0, 'Итоговая стоимость товара'] = df['Итоговая стоимость товара'] / 2
df_new.head(5)
# Out:
# <ipython-input-13-2d4cc6e5265f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["Indexes"]= df_new['Наименование товара'].str.find(sub)
#                                  Наименование товара  Артикул  \
# 1  Чайный напиток травяной листья Брусники ф/п 1,...   697461
# 2  Чай травяной Друг Вашего желудка 2 пачки /40 ф...   689741
# 3  Чай травяной детская линия Сказка на ночь ф/п ...    71002
# 4  Чайный напиток травяной листья Брусники ф/п 1,...   697461
# 5  Чай травяной детская линия Комфорт в боботике ...    71003
#
#    Итоговая стоимость товара  Количество  Indexes
# 1                      166.5           2       49
# 2                      179.5           2       33
# 3                      189.0           1       -1
# 4                      166.5           2       49
# 5                      189.0           1       -1

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, 1 to 37
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Наименование товара        36 non-null     object
#  1   Артикул                    36 non-null     int64
#  2   Итоговая стоимость товара  36 non-null     float64
#  3   Количество                 36 non-null     int64
#  4   Indexes                    36 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.7+ KB

# %%
df_new['art_str'] = df_new['Артикул'].astype(str)
# df_new['len_new_art'] = df_new['art_str'].str.len()
df_new["art_str"] = df_new["art_str"].str[:5]
df_new['Артикул'] = df_new['art_str'].astype('int32')
df_new.head(5)
# Out:
# <ipython-input-15-4d403d3da565>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['art_str'] = df_new['Артикул'].astype(str)
# <ipython-input-15-4d403d3da565>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["art_str"] = df_new["art_str"].str[:5]
# <ipython-input-15-4d403d3da565>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['Артикул'] = df_new['art_str'].astype('int32')
#                                  Наименование товара  Артикул  \
# 1  Чайный напиток травяной листья Брусники ф/п 1,...    69746
# 2  Чай травяной Друг Вашего желудка 2 пачки /40 ф...    68974
# 3  Чай травяной детская линия Сказка на ночь ф/п ...    71002
# 4  Чайный напиток травяной листья Брусники ф/п 1,...    69746
# 5  Чай травяной детская линия Комфорт в боботике ...    71003
#
#    Итоговая стоимость товара  Количество  Indexes art_str
# 1                      166.5           2       49   69746
# 2                      179.5           2       33   68974
# 3                      189.0           1       -1   71002
# 4                      166.5           2       49   69746
# 5                      189.0           1       -1   71003

# %%
df_new.to_excel('/content/orders_new.xlsx')
# df_new.to_csv('/content/orders_new.csv')
