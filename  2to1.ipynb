# %% [markdown]
# <a href="https://colab.research.google.com/github/dim447/data_analyst/blob/main/%202to1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Задачи исследования**
#
# ### Загружаем данные и меняем с 2 пачки на 1.

# %%
### Загружаем данные и объединяем семь датасетов
import pandas as pd
import numpy as np
from datetime import datetime


df = pd.read_csv('/content/orders.csv', sep=';')

# %%
df.head(5)
# Out:
#       Номер заказа  Номер отправления   Принят в обработку  \
# 0    01894310-0138    01894310-0138-1  2024-03-05 20:46:51
# 1    35091528-0258    35091528-0258-2  2024-03-05 19:35:13
# 2  0125010736-0189  0125010736-0189-1  2024-03-05 18:14:39
# 3    41733642-0122    41733642-0122-1  2024-03-05 17:42:46
# 4    91824642-0150    91824642-0150-1  2024-03-05 16:45:49
#
#          Дата отгрузки            Статус  Дата доставки  Сумма отправления  \
# 0  2024-03-06 17:00:00  Ожидает отгрузки            NaN              191.0
# 1  2024-03-06 08:00:00  Ожидает отгрузки            NaN              348.0
# 2  2024-03-06 10:00:00      Доставляется            NaN              348.0
# 3  2024-03-06 14:30:00  Ожидает отгрузки            NaN              348.0
# 4  2024-03-06 01:00:00      Доставляется            NaN              348.0
#
#   Код валюты отправления                                Наименование товара  \
# 0                    RUB  Чайный напиток травяной листья Брусники ф/п 1,...
# 1                    RUB  Чай травяной Друг Вашего сердца 2 пачки /40 фи...
# 2                    RUB  Чай травяной Друг Вашего сна 2 пачки /40 фильт...
# 3                    RUB  Чай травяной Друг Ваших почек 2 пачки /40 филь...
# 4                    RUB  Чай травяной Друг Ваших почек 2 пачки /40 филь...
#
#       OZON id  ...  Код валюты товара  Количество Стоимость доставки  \
# 0   479931465  ...                RUB           1                NaN
# 1  1225943066  ...                RUB           1                NaN
# 2  1227073399  ...                RUB           1                NaN
# 3  1225942965  ...                RUB           1                NaN
# 4  1225942965  ...                RUB           1                NaN
#
#    Связанные отправления  Выкуп товара  Цена товара до скидок  Скидка %  \
# 0                    NaN           NaN                  399.0       52%
# 1                    NaN           NaN                  799.0       56%
# 2                    NaN           NaN                  799.0       56%
# 3                    NaN           NaN                  799.0       56%
# 4                    NaN           NaN                  799.0       56%
#
#    Скидка руб                                              Акции  \
# 0       208.0  Радуй и Удивляй распродажи. СуперХиты, Системн...
# 1       451.0  Системная виртуальная скидка селлера, Радуй и ...
# 2       451.0  Радуй и Удивляй распродажи. СуперХиты, Системн...
# 3       451.0  Системная виртуальная скидка селлера, Радуй и ...
# 4       451.0  Системная виртуальная скидка селлера, Радуй и ...
#
#    Объемный вес товаров, кг
# 0                       0.1
# 1                       0.2
# 2                       0.2
# 3                       0.2
# 4                       0.2
#
# [5 rows x 22 columns]

# %%
df_new = df[['Наименование товара', 'Артикул', 'Итоговая стоимость товара', 'Количество']]
df_new.head(5)
# Out:
#                                  Наименование товара  Артикул  \
# 0  Чайный напиток травяной листья Брусники ф/п 1,...    69746
# 1  Чай травяной Друг Вашего сердца 2 пачки /40 фи...   689641
# 2  Чай травяной Друг Вашего сна 2 пачки /40 фильт...   689621
# 3  Чай травяной Друг Ваших почек 2 пачки /40 филь...   689661
# 4  Чай травяной Друг Ваших почек 2 пачки /40 филь...   689661
#
#    Итоговая стоимость товара  Количество
# 0                      191.0           1
# 1                      348.0           1
# 2                      348.0           1
# 3                      348.0           1
# 4                      348.0           1

# %%
sub ='2 пачки'
df_new["Indexes"]= df_new['Наименование товара'].str.find(sub)
df_new.loc[df_new["Indexes"] >= 0, 'Количество'] = 2
df_new.head(5)
# Out:
# <ipython-input-4-54106df405bb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["Indexes"]= df_new['Наименование товара'].str.find(sub)
#                                  Наименование товара  Артикул  \
# 0  Чайный напиток травяной листья Брусники ф/п 1,...    69746
# 1  Чай травяной Друг Вашего сердца 2 пачки /40 фи...   689641
# 2  Чай травяной Друг Вашего сна 2 пачки /40 фильт...   689621
# 3  Чай травяной Друг Ваших почек 2 пачки /40 филь...   689661
# 4  Чай травяной Друг Ваших почек 2 пачки /40 филь...   689661
#
#    Итоговая стоимость товара  Количество  Indexes
# 0                      191.0           1       -1
# 1                      348.0           2       32
# 2                      348.0           2       29
# 3                      348.0           2       30
# 4                      348.0           2       30

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Наименование товара        21 non-null     object
#  1   Артикул                    21 non-null     int64
#  2   Итоговая стоимость товара  21 non-null     float64
#  3   Количество                 21 non-null     int64
#  4   Indexes                    21 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 968.0+ bytes

# %%
df_new['art_str'] = df_new['Артикул'].astype(str)
# df_new['len_new_art'] = df_new['art_str'].str.len()
df_new["art_str"] = df_new["art_str"].str[:5]
df_new['Артикул'] = df_new['art_str'].astype('int32')
df_new.head(5)
# Out:
# <ipython-input-6-4d403d3da565>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['art_str'] = df_new['Артикул'].astype(str)
# <ipython-input-6-4d403d3da565>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["art_str"] = df_new["art_str"].str[:5]
# <ipython-input-6-4d403d3da565>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['Артикул'] = df_new['art_str'].astype('int32')
#                                  Наименование товара  Артикул  \
# 0  Чайный напиток травяной листья Брусники ф/п 1,...    69746
# 1  Чай травяной Друг Вашего сердца 2 пачки /40 фи...    68964
# 2  Чай травяной Друг Вашего сна 2 пачки /40 фильт...    68962
# 3  Чай травяной Друг Ваших почек 2 пачки /40 филь...    68966
# 4  Чай травяной Друг Ваших почек 2 пачки /40 филь...    68966
#
#    Итоговая стоимость товара  Количество  Indexes art_str
# 0                      191.0           1       -1   69746
# 1                      348.0           2       32   68964
# 2                      348.0           2       29   68962
# 3                      348.0           2       30   68966
# 4                      348.0           2       30   68966

# %%
df_new.to_excel('/content/orders_new.xlsx')
# df_new.to_csv('/content/orders_new.csv')
