# %% [markdown]
# <a href="https://colab.research.google.com/github/dim447/data_analyst/blob/main/%202to1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Задачи исследования**
#
# ### Загружаем данные и меняем с 2 пачки на 1.

# %%
### Загружаем данные продаж за период (orders.csv)
import pandas as pd
import numpy as np
from datetime import datetime


df = pd.read_csv('/content/orders.csv', sep=';')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 25 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Номер заказа                          35 non-null     object
#  1   Номер отправления                     35 non-null     object
#  2   Принят в обработку                    35 non-null     object
#  3   Дата отгрузки                         34 non-null     object
#  4   Статус                                35 non-null     object
#  5   Дата доставки                         0 non-null      float64
#  6   Фактическая дата передачи в доставку  26 non-null     object
#  7   Сумма отправления                     35 non-null     float64
#  8   Код валюты отправления                35 non-null     object
#  9   Наименование товара                   35 non-null     object
#  10  OZON id                               35 non-null     int64
#  11  Артикул                               35 non-null     int64
#  12  Итоговая стоимость товара             35 non-null     float64
#  13  Код валюты товара                     35 non-null     object
#  14  Стоимость товара для покупателя       35 non-null     float64
#  15  Код валюты покупателя                 35 non-null     object
#  16  Количество                            35 non-null     int64
#  17  Стоимость доставки                    0 non-null      float64
#  18  Связанные отправления                 0 non-null      float64
#  19  Выкуп товара                          0 non-null      float64
#  20  Цена товара до скидок                 35 non-null     float64
#  21  Скидка %                              35 non-null     object
#  22  Скидка руб                            35 non-null     float64
#  23  Акции                                 35 non-null     object
#  24  Объемный вес товаров, кг              35 non-null     float64
# dtypes: float64(10), int64(3), object(12)
# memory usage: 7.0+ KB

# %%
### Убираем товары со статусом "Отменен"
df = df.loc[df['Статус'] != 'Отменён']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 0 to 34
# Data columns (total 25 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Номер заказа                          34 non-null     object
#  1   Номер отправления                     34 non-null     object
#  2   Принят в обработку                    34 non-null     object
#  3   Дата отгрузки                         33 non-null     object
#  4   Статус                                34 non-null     object
#  5   Дата доставки                         0 non-null      float64
#  6   Фактическая дата передачи в доставку  26 non-null     object
#  7   Сумма отправления                     34 non-null     float64
#  8   Код валюты отправления                34 non-null     object
#  9   Наименование товара                   34 non-null     object
#  10  OZON id                               34 non-null     int64
#  11  Артикул                               34 non-null     object
#  12  Итоговая стоимость товара             34 non-null     float64
#  13  Код валюты товара                     34 non-null     object
#  14  Стоимость товара для покупателя       34 non-null     float64
#  15  Код валюты покупателя                 34 non-null     object
#  16  Количество                            34 non-null     int64
#  17  Стоимость доставки                    0 non-null      float64
#  18  Связанные отправления                 0 non-null      float64
#  19  Выкуп товара                          0 non-null      float64
#  20  Цена товара до скидок                 34 non-null     float64
#  21  Скидка %                              34 non-null     object
#  22  Скидка руб                            34 non-null     float64
#  23  Акции                                 34 non-null     object
#  24  Объемный вес товаров, кг              34 non-null     float64
# dtypes: float64(10), int64(2), object(13)
# memory usage: 6.9+ KB

# %%
### приводим значения артикулов с формату "Моя торговля"
df['Артикул'] = df['Артикул'].apply(lambda x: str(x)[:5] if len(str(x)) == 6
                                    else str(x)[:3] if len(str(x)) == 4
                                    else str(x))
# Out:
# <ipython-input-3-6900ba94518d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Артикул'] = df['Артикул'].apply(lambda x: str(x)[:5] if len(str(x)) == 6

# %%
### Оставляем для импорта только эти данные
df_new = df[['Наименование товара', 'Артикул', 'Итоговая стоимость товара', 'Количество']]

# %%
### Если в названии есть "2 пачки", то меняем количество на 2 и стоимость делим на 2
sub ='2 пачки'
df_new["Indexes"]= df_new['Наименование товара'].str.find(sub)
df_new.loc[df_new["Indexes"] >= 0, 'Количество'] = 2
df_new.loc[df_new["Indexes"] >= 0, 'Итоговая стоимость товара'] = df['Итоговая стоимость товара'] / 2
df_new.head(10)
# Out:
# <ipython-input-5-b399704f9f03>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["Indexes"]= df_new['Наименование товара'].str.find(sub)
#                                  Наименование товара Артикул  \
# 0  "Целебная Поляна" Травяной сбор / Друг Ваших с...   68970
# 1  Чай травяной детская линия Комфорт в боботике ...   71003
# 2  Чай травяной детская линия Комфорт в боботике ...   71003
# 3  Фитосбор "Для почек", 2 пачки по 20 фильтр-пак...   62995
# 4  Чай травяной детская линия Комфорт в боботике ...   71003
# 5  Чай травяной детская линия "Фитосбор Грудной" ...   71004
# 6  Чай травяной Друг Вашего давления 2 пачки /40 ...   68968
# 7  Чай травяной детская линия Комфорт в боботике ...   71003
# 8  Чай травяной Друг Вашей поджелудочной железы 2...   68965
# 9  "Целебная Поляна" Травяной сбор / Друг Вашего ...   68962
#
#    Итоговая стоимость товара  Количество  Indexes
# 0                      154.5           2       54
# 1                      189.0           1       -1
# 2                      189.0           1       -1
# 3                      158.5           2       22
# 4                      189.0           1       -1
# 5                      197.0           1       -1
# 6                      165.0           2       34
# 7                      189.0           1       -1
# 8                      165.5           2       45
# 9                      169.0           2       50

# %%
### Сохраняем в файл для импорта
df_new.to_excel('/content/orders_new.xlsx')
# df_new.to_csv('/content/orders_new.csv')
