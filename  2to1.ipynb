# %% [markdown]
# <a href="https://colab.research.google.com/github/dim447/data_analyst/blob/main/%202to1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Задачи исследования**
#
# ### Загружаем данные и меняем с 2 пачки на 1.

# %%
### Загружаем данные и объединяем семь датасетов
import pandas as pd
import numpy as np
from datetime import datetime


df = pd.read_csv('/content/orders.csv', sep=';')

# %%
df.head(5)
# Out:
#       Номер заказа  Номер отправления   Принят в обработку  \
# 0  0152775070-0007  0152775070-0007-1  2024-04-02 20:31:00
# 1    20649207-0241    20649207-0241-1  2024-04-02 20:10:33
# 2    17509151-0188    17509151-0188-1  2024-04-02 19:45:16
# 3    52644047-0591    52644047-0591-3  2024-04-02 19:04:04
# 4  0128012146-0053  0128012146-0053-5  2024-04-02 18:12:59
#
#          Дата отгрузки            Статус  Дата доставки  Сумма отправления  \
# 0  2024-04-03 01:00:00      Доставляется            NaN              209.0
# 1  2024-04-03 10:30:00  Ожидает отгрузки            NaN              359.0
# 2  2024-04-03 01:00:00      Доставляется            NaN              348.0
# 3  2024-04-03 10:00:00  Ожидает отгрузки            NaN              338.0
# 4  2024-04-03 22:00:00    Ожидает сборки            NaN              330.0
#
#   Код валюты отправления                                Наименование товара  \
# 0                    RUB  Чай травяной Друг Вашего сна ф/п 1.5г №20 / 20...
# 1                    RUB  Чай травяной Друг Вашего желудка 2 пачки /40 ф...
# 2                    RUB  "Целебная поляна" Травяной сбор / Друг Ваших п...
# 3                    RUB  Чайный напиток травяной листья Брусники ф/п 1,...
# 4                    RUB  Чайный напиток травяной Череды трава ф/п 1,5г ...
#
#       OZON id  ...  Код валюты товара  Количество Стоимость доставки  \
# 0   482739289  ...                RUB           1                NaN
# 1  1225949560  ...                RUB           1                NaN
# 2  1225942965  ...                RUB           1                NaN
# 3  1311870665  ...                RUB           1                NaN
# 4  1329485527  ...                RUB           1                NaN
#
#    Связанные отправления  Выкуп товара  Цена товара до скидок  Скидка %  \
# 0                    NaN           NaN                  400.0       48%
# 1                    NaN           NaN                  799.0       55%
# 2                    NaN           NaN                  799.0       56%
# 3                    NaN           NaN                  799.0       58%
# 4                    NaN           NaN                  799.0       59%
#
#    Скидка руб                                              Акции  \
# 0       191.0  Системная виртуальная скидка селлера, Радуй и ...
# 1       440.0  Системная виртуальная скидка селлера, Радуй и ...
# 2       451.0  Системная виртуальная скидка селлера, Радуй и ...
# 3       461.0  Системная виртуальная скидка селлера, Хиты. Бе...
# 4       469.0  Системная виртуальная скидка селлера, Радуй и ...
#
#    Объемный вес товаров, кг
# 0                       0.1
# 1                       0.2
# 2                       0.2
# 3                       0.2
# 4                       0.2
#
# [5 rows x 22 columns]

# %%
df_new = df[['Наименование товара', 'Артикул', 'Итоговая стоимость товара', 'Количество']]
df_new.head(5)
# Out:
#                                  Наименование товара  Артикул  \
# 0  Чай травяной Друг Вашего сна ф/п 1.5г №20 / 20...    68962
# 1  Чай травяной Друг Вашего желудка 2 пачки /40 ф...   689741
# 2  "Целебная поляна" Травяной сбор / Друг Ваших п...   689661
# 3  Чайный напиток травяной листья Брусники ф/п 1,...   697461
# 4  Чайный напиток травяной Череды трава ф/п 1,5г ...    76702
#
#    Итоговая стоимость товара  Количество
# 0                      209.0           1
# 1                      359.0           1
# 2                      348.0           1
# 3                      338.0           1
# 4                      330.0           1

# %%
sub ='2 пачки'
df_new["Indexes"]= df_new['Наименование товара'].str.find(sub)
df_new.loc[df_new["Indexes"] >= 0, 'Количество'] = 2
df_new.loc[df_new["Indexes"] >= 0, 'Итоговая стоимость товара'] = df['Итоговая стоимость товара'] / 2
df_new.head(5)
# Out:
# <ipython-input-19-2d4cc6e5265f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["Indexes"]= df_new['Наименование товара'].str.find(sub)
#                                  Наименование товара  Артикул  \
# 0  Чай травяной Друг Вашего сна ф/п 1.5г №20 / 20...    68962
# 1  Чай травяной Друг Вашего желудка 2 пачки /40 ф...   689741
# 2  "Целебная поляна" Травяной сбор / Друг Ваших п...   689661
# 3  Чайный напиток травяной листья Брусники ф/п 1,...   697461
# 4  Чайный напиток травяной Череды трава ф/п 1,5г ...    76702
#
#    Итоговая стоимость товара  Количество  Indexes
# 0                      209.0           1       -1
# 1                      179.5           2       33
# 2                      174.0           2       51
# 3                      169.0           2       49
# 4                      165.0           2       46

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Наименование товара        33 non-null     object
#  1   Артикул                    33 non-null     int64
#  2   Итоговая стоимость товара  33 non-null     float64
#  3   Количество                 33 non-null     int64
#  4   Indexes                    33 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df_new['art_str'] = df_new['Артикул'].astype(str)
# df_new['len_new_art'] = df_new['art_str'].str.len()
df_new["art_str"] = df_new["art_str"].str[:5]
df_new['Артикул'] = df_new['art_str'].astype('int32')
df_new.head(5)
# Out:
# <ipython-input-21-4d403d3da565>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['art_str'] = df_new['Артикул'].astype(str)
# <ipython-input-21-4d403d3da565>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["art_str"] = df_new["art_str"].str[:5]
# <ipython-input-21-4d403d3da565>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['Артикул'] = df_new['art_str'].astype('int32')
#                                  Наименование товара  Артикул  \
# 0  Чай травяной Друг Вашего сна ф/п 1.5г №20 / 20...    68962
# 1  Чай травяной Друг Вашего желудка 2 пачки /40 ф...    68974
# 2  "Целебная поляна" Травяной сбор / Друг Ваших п...    68966
# 3  Чайный напиток травяной листья Брусники ф/п 1,...    69746
# 4  Чайный напиток травяной Череды трава ф/п 1,5г ...    76702
#
#    Итоговая стоимость товара  Количество  Indexes art_str
# 0                      209.0           1       -1   68962
# 1                      179.5           2       33   68974
# 2                      174.0           2       51   68966
# 3                      169.0           2       49   69746
# 4                      165.0           2       46   76702

# %%
df_new.to_excel('/content/orders_new.xlsx')
# df_new.to_csv('/content/orders_new.csv')
